# %% [markdown]
# 1)Import python libraries

# %%
import pandas as pd
import matplotlib as mlp
import seaborn as sns

# %% [markdown]
# 3)Load datasets into panda data frames

# %%
df=pd.read_csv("movies.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.read_csv("movies.csv")
#
# File C:\Python310\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
# ...

# %% [markdown]
# 4) Data Preprocessing

# %%
df.head()                       ##first five values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()                       ##first five values
#
# NameError: name 'df' is not defined

# %% [markdown]
# "Type os columns"

# %%
df['YEAR'].dtype
# Out:
# dtype('O')

# %%
df['RunTime'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# MOVIES       object
# YEAR         object
# GENRE        object
# RATING      float64
# ONE-LINE     object
# STARS        object
# VOTES        object
# RunTime     float64
# Gross        object
# dtype: object

# %%
df.isnull()                     ##Check for null values
# Out:
#       MOVIES   YEAR  GENRE  RATING  ONE-LINE  STARS  VOTES  RunTime  Gross
# 0      False  False  False   False     False  False  False    False   True
# 1      False  False  False   False     False  False  False    False   True
# 2      False  False  False   False     False  False  False    False   True
# 3      False  False  False   False     False  False  False    False   True
# 4      False  False  False    True     False  False   True     True   True
# ...      ...    ...    ...     ...       ...    ...    ...      ...    ...
# 9994   False  False  False    True     False  False   True     True   True
# 9995   False  False  False    True     False  False   True     True   True
# 9996   False  False  False    True     False  False   True     True   True
# 9997   False  False  False    True     False  False   True     True   True
# 9998   False  False  False    True     False  False   True     True   True
#
# [9999 rows x 9 columns]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 89991

# %%
df.describe()
# Out:
#             RATING      RunTime
# count  8179.000000  7041.000000
# mean      6.921176    68.688539
# std       1.220232    47.258056
# min       1.100000     1.000000
# 25%       6.200000    36.000000
# 50%       7.100000    60.000000
# 75%       7.800000    95.000000
# max       9.900000   853.000000

# %%
df.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
df.dropna(axis=0,inplace=True)               ##drop rows having null values

# %%
df.head()
# Out:
#                                                 MOVIES        YEAR  \
# 77                              The Hitman's Bodyguard      (2017)
# 85                                       Jurassic Park      (1993)
# 95                                       Don't Breathe      (2016)
# 111  The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                        Escape Room  (I) (2019)
#
#                                        GENRE  RATING  \
# 77       \nAction, Comedy, Crime                 6.9
# 85   \nAction, Adventure, Sci-Fi                 8.1
# 95     \nCrime, Horror, Thriller                 7.1
# 111   \nAction, Adventure, Drama                 8.8
# 125  \nAction, Adventure, Horror                 6.4
#
#                                               ONE-LINE  \
# 77   \nThe world's top bodyguard gets a new client,...
# 85   \nA pragmatic paleontologist visiting an almos...
# 95   \nHoping to walk away with a massive fortune, ...
# ...

# %%
df.isnull()
# Out:
#       MOVIES   YEAR  GENRE  RATING  ONE-LINE  STARS  VOTES  RunTime  Gross
# 77     False  False  False   False     False  False  False    False  False
# 85     False  False  False   False     False  False  False    False  False
# 95     False  False  False   False     False  False  False    False  False
# 111    False  False  False   False     False  False  False    False  False
# 125    False  False  False   False     False  False  False    False  False
# ...      ...    ...    ...     ...       ...    ...    ...      ...    ...
# 5750   False  False  False   False     False  False  False    False  False
# 5770   False  False  False   False     False  False  False    False  False
# 5835   False  False  False   False     False  False  False    False  False
# 6056   False  False  False   False     False  False  False    False  False
# 6292   False  False  False   False     False  False  False    False  False
#
# [460 rows x 9 columns]

# %% [markdown]
# 5) Data Normalization

# %%
df.describe()
# Out:
#            RATING     RunTime
# count  460.000000  460.000000
# mean     6.638043  106.436957
# std      0.940894   21.380930
# min      3.100000   24.000000
# 25%      6.100000   93.000000
# 50%      6.600000  103.000000
# 75%      7.300000  116.000000
# max      8.900000  228.000000

# %%
df_new=df.copy()                     #copy to new data frame
df_new['RunTime']=(df_new['RunTime']-df_new['RunTime'].min())/(df_new['RunTime'].max()-df_new['RunTime'].min())
df_new.head()
# Out:
#                                                 MOVIES        YEAR  \
# 77                              The Hitman's Bodyguard      (2017)
# 85                                       Jurassic Park      (1993)
# 95                                       Don't Breathe      (2016)
# 111  The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                        Escape Room  (I) (2019)
#
#                                        GENRE  RATING  \
# 77       \nAction, Comedy, Crime                 6.9
# 85   \nAction, Adventure, Sci-Fi                 8.1
# 95     \nCrime, Horror, Thriller                 7.1
# 111   \nAction, Adventure, Drama                 8.8
# 125  \nAction, Adventure, Horror                 6.4
#
#                                               ONE-LINE  \
# 77   \nThe world's top bodyguard gets a new client,...
# 85   \nA pragmatic paleontologist visiting an almos...
# 95   \nHoping to walk away with a massive fortune, ...
# ...

# %% [markdown]
# 6)Categorical variables into quantitative variables

# %%
df['YEAR'].replace(['(1993)','(2017)'],[0,1])
# Out:
# 77               1
# 85               0
# 95          (2016)
# 111         (2001)
# 125     (I) (2019)
#            ...
# 5750        (2010)
# 5770        (2012)
# 5835        (2012)
# 6056        (2016)
# 6292        (2006)
# Name: YEAR, Length: 460, dtype: object
